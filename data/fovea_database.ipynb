# %%
import numpy as np
import pandas as pd
import os 
import io

# %%
GA_folder = 'R:\Ophthalmology\Mirza_Images\AMD\dAMD_GA'

# Get folder names
subfolder_names = os.listdir(GA_folder)
subfolders = []
subfolder_paths = []
for subfolder_name in subfolder_names:
    if os.path.isdir(os.path.join(GA_folder, subfolder_name)):
        subfolders.append(subfolder_name)
        subfolder_paths.append(os.path.join(GA_folder, subfolder_name))

# print(subfolders)

# %%
# Get Patient_ID
patient_id_list = []

# Right eye or left eye?
patient_eye = []

for folder_name in subfolders:
    patient_id_list.append(folder_name[0:3])
    
    if folder_name[4:6] == 'OS':
        patient_eye.append('left')
    else:
        patient_eye.append('right')
    
# print(patient_id_list)
print(patient_eye)

# %%
# Creating a CSV for the data
data = pd.DataFrame(list(zip(subfolders, patient_id_list, patient_eye)), columns=['folder', 'patient_id', 'eye_side'])

# %%
data.head()

# %%
per_scan_data = pd.DataFrame(columns = ['scan_name', 'scan_number', 'folder_name', 'patient_id', 'eye_side','status', 'distance'])
per_scan_data

# %%
## Every picture

# go to each subfolder and make a row for each picture.
subfolder_names2 = os.listdir(GA_folder)
subfolders2 = []
subfolder_paths2 = []
picture_names=[]
for subfolder_name in subfolder_names2:
    if os.path.isdir(os.path.join(GA_folder, subfolder_name+"/500_slices")):
        scan_name_list = os.path.join(GA_folder, subfolder_name+"/500_slices")
        picture_names.append(os.listdir(scan_name_list))

# %%
print(len(picture_names))
print(len(picture_names[0]))

# %%
for file_content in picture_names:
    for picture in file_content:
        data_per = []
        
        splat = picture.split("_")
        
        ## get scan_name
        data_per.append(picture)
        
        ## get scan number 
        scan_number = int(splat[7].split(".")[0])
        data_per.append(scan_number)

        ## get folder name
        splat2 = splat[0:7]
        folder_name = "_".join(splat2)
        data_per.append(folder_name)
        
        ## get patient_id
        data_per.append(splat[0])
        
        ## get left or right eye
        if splat[1] == 'OS':
            data_per.append('left')
        else:
            data_per.append('right')
        
        ## status
        # data_per.append('None')

        distance_per = []

        ## check folder name
        if folder_name == '047_OS_1_GA_6x6_SSOCT_1': #1
            if (scan_number < 270 or scan_number > 352):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.append(min(abs(270-scan_number), abs(452-scan_number)))
#                 per_scan_data['distance']=min(abs(270-scan_number), abs(452-scan_number))
    
                
        elif folder_name == '047_OS_2_GA_6x6_SSOCT_1': #3
            if (scan_number < 285 or scan_number > 359):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.append(min(abs(285-scan_number), abs(359-scan_number)))
#                 per_scan_data['distance']=min(abs(285-scan_number), abs(359-scan_number))
        elif folder_name == '064_OD_1_GA_6x6_SSOCT_1': #5
            if (scan_number < 241 or scan_number > 336):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.append(min(abs(241-scan_number), abs(336-scan_number)))
#                 per_scan_data['distance']=min(abs(241-scan_number), abs(336-scan_number))
        elif folder_name == '064_OD_1_GA_6x6_SSOCT_2': #7
            if (scan_number < 238 or scan_number > 337):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.append(min(abs(238-scan_number), abs(337-scan_number)))
#                 per_scan_data['distance']=min(abs(238-scan_number), abs(337-scan_number))
        elif folder_name == '064_OD_2_GA_6x6_SSOCT_1': #9
            if (scan_number < 185 or scan_number > 321):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.append(min(abs(185-scan_number), abs(321-scan_number)))
#                 per_scan_data['distance']=min(abs(185-scan_number), abs(321-scan_number))
        elif folder_name == '064_OD_3_GA_6x6_SSOCT_1': #11
            if (scan_number < 185 or scan_number > 326):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.append(min(abs(185-scan_number), abs(326-scan_number)))
#                 per_scan_data['distance']=min(abs(185-scan_number), abs(326-scan_number))
        elif folder_name == '064_OD_4_GA_6x6_SSOCT_1': #13
            if (scan_number < 170 or scan_number > 307):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.append(min(abs(170-scan_number), abs(307-scan_number)))
#                 per_scan_data['distance']=min(abs(170-scan_number), abs(307-scan_number))
        elif folder_name == '064_OD_5_GA_6x6_SSOCT_1': #15
            if (scan_number < 241 or scan_number > 377):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.apped(min(abs(241-scan_number), abs(377-scan_number)))
#                 per_scan_data['distance']=min(abs(241-scan_number), abs(377-scan_number))
        elif folder_name == '064_OD_5_GA_6x6_SSOCT_2': #17
            if (scan_number < 229 or scan_number > 371):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.append(min(abs(229-scan_number), abs(371-scan_number)))
#                 per_scan_data['distance']=min(abs(229-scan_number), abs(371-scan_number))
        elif folder_name == '064_OD_6_GA_6x6_SSOCT_1': #19
            if (scan_number < 217 or scan_number > 366):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.append(min(abs(217-scan_number), abs(366-scan_number)))
#                 per_scan_data['distance']=min(abs(217-scan_number), abs(366-scan_number))
        elif folder_name == '064_OD_6_GA_6x6_SSOCT_2': #21
            if (scan_number < 184 or scan_number > 336):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.append(min(abs(184-scan_number), abs(336-scan_number)))
#                 per_scan_data['distance']=min(abs(184-scan_number), abs(336-scan_number))
        elif folder_name == '064_OD_7_GA_6x6_SSOCT_1': #23
            if (scan_number < 195 or scan_number > 352):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.append(min(abs(195-scan_number), abs(352-scan_number)))
#                 per_scan_data['distance']=min(abs(195-scan_number), abs(352-scan_number))
        elif folder_name == '064_OD_7_GA_6x6_SSOCT_2': #25
            if (scan_number < 160 or scan_number > 317):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.append(min(abs(160-scan_number), abs(317-scan_number)))
#                 per_scan_data['distance']=min(abs(160-scan_number), abs(317-scan_number))
        elif folder_name == '064_OD_7_GA_6x6_SSOCT_3': #27
            if (scan_number < 128 or scan_number > 286):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.append(min(abs(128-scan_number), abs(286-scan_number)))
#                 per_scan_data['distance']=min(abs(128-scan_number), abs(286-scan_number))
        elif folder_name == '064_OD_8_GA_6x6_SSOCT_1': #29
            if (scan_number < 171 or scan_number > 331):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.append(min(abs(171-scan_number), abs(331-scan_number)))
#                 per_scan_data['distance']=min(abs(171-scan_number), abs(331-scan_number))
        elif folder_name == '064_OD_9_GA_6x6_SSOCT_1': #31
            if (scan_number < 167 or scan_number > 330):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.append(min(abs(167-scan_number), abs(330-scan_number)))
#                 per_scan_data['distance']=min(abs(167-scan_number), abs(330-scan_number))
        elif folder_name == '064_OD_10_GA_6x6_SSOCT_1': #33
            if (scan_number < 159 or scan_number > 332):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.append(min(abs(159-scan_number), abs(332-scan_number)))
#                 per_scan_data['distance']=min(abs(159-scan_number), abs(332-scan_number))
        elif folder_name == '064_OS_1_GA_6x6_SSOCT_1': #35
            if (scan_number < 220 or scan_number > 389):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.append(min(abs(220-scan_number), abs(389-scan_number)))
#                 per_scan_data['distance']=min(abs(220-scan_number), abs(389-scan_number))
        elif folder_name == '064_OS_1_GA_6x6_SSOCT_2': #37
            if (scan_number < 168 or scan_number > 340):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.append(min(abs(168-scan_number), abs(340-scan_number)))
#                 per_scan_data['distance']=min(abs(168-scan_number), abs(340-scan_number))
        elif folder_name == '064_OS_2_GA_6x6_SSOCT_1': #39
            if (scan_number < 180 or scan_number > 359):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.append(min(abs(180-scan_number), abs(359-scan_number)))
#                 per_scan_data['distance']=min(abs(180-scan_number), abs(359-scan_number))
        elif folder_name == '064_OS_2_GA_6x6_SSOCT_2': #41
            if (scan_number < 174 or scan_number > 354):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.append(min(abs(174-scan_number), abs(354-scan_number)))
#                 per_scan_data['distance']=min(abs(174-scan_number), abs(354-scan_number))
        elif folder_name == '064_OS_3_GA_6x6_SSOCT_1': #43
            if (scan_number < 187 or scan_number > 371):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.append(min(abs(187-scan_number), abs(371-scan_number)))
#                 per_scan_data['distance']=min(abs(187-scan_number), abs(371-scan_number))
        elif folder_name == '064_OS_4_GA_6x6_SSOCT_1': #45
            if (scan_number < 188 or scan_number > 372):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.append(min(abs(188-scan_number), abs(372-scan_number)))
#                 per_scan_data['distance']=min(abs(188-scan_number), abs(372-scan_number))
        elif folder_name == '064_OS_5_GA_6x6_SSOCT_1': #47
            if (scan_number < 180 or scan_number > 368):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.append(min(abs(180-scan_number), abs(368-scan_number)))
#                 per_scan_data['distance']=min(abs(180-scan_number), abs(368-scan_number))
        elif folder_name == '064_OS_6_GA_6x6_SSOCT_1': #49
            if (scan_number < 172 or scan_number > 362):
                data_per.append(False)
            else:
                data_per.append(True)
        elif folder_name == '190_OD_1_GA_6x6_SSOCT_1': #51
            ## changed it a bit
            if (scan_number>=209 and scan_number<=219)or(scan_number>=265 and scan_number<=295)or(scan_number>=335 and scan_number<=362):
                data_per.append(True)
                if (scan_number>=209 and scan_number<=219):
                    distance_per.append(in(abs(209-scan_number), abs(219-scan_number)))
#                     per_scan_data['distance']=min(abs(209-scan_number), abs(219-scan_number))
                elif (scan_number>=265 and scan_number<=295):
                    distance_per.append(min(abs(265-scan_number), abs(295-scan_number)))
#                     per_scan_data['distance']=min(abs(265-scan_number), abs(295-scan_number))
                else: 
                    distance_per.append(min(abs(335-scan_number), abs(362-scan_number)))
#                     per_scan_data['distance']=min(abs(335-scan_number), abs(362-scan_number))
            else:
                data_per.append(False)
        elif folder_name == '190_OS_1_GA_6x6_SSOCT_1': #55
            ## changed it a bit
            if (scan_number>=152 and scan_number<=168)or(scan_number>=242 and scan_number<=328)or(scan_number>=355 and scan_number<=366):
                data_per.append(True)
                if (scan_number>=152 and scan_number<=168):
                    distance_per.append(min(abs(152-scan_number), abs(168-scan_number)))
#                     per_scan_data['distance']=min(abs(152-scan_number), abs(168-scan_number))
                elif (scan_number>=242 and scan_number<=328):
                    distance_per.append(min(abs(242-scan_number), abs(328-scan_number)))
#                     per_scan_data['distance']=min(abs(242-scan_number), abs(328-scan_number))
                else: 
                    distance_per.append(min(abs(355-scan_number), abs(366-scan_number)))
#                     per_scan_data['distance']=min(abs(355-scan_number), abs(366-scan_number))
            else:
                data_per.append(False)
        elif folder_name == '321_OD_1_GA_6x6_SSOCT_1': #59
            if (scan_number < 9 or scan_number > 230):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.append(min(abs(9-scan_number), abs(230-scan_number)))
#                 per_scan_data['distance']=min(abs(9-scan_number), abs(230-scan_number))
        elif folder_name == '321_OS_1_GA_6x6_SSOCT_1': #61
            if (scan_number < 51 or scan_number > 374):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.append(min(abs(51-scan_number), abs(374-scan_number)))
#                 per_scan_data['distance']=min(abs(51-scan_number), abs(374-scan_number))
        elif folder_name == '326_OD_1_GA_6x6_SSOCT_1': #63
            if (scan_number < 208 or scan_number > 248):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.append(min(abs(208-scan_number), abs(248-scan_number)))
#                 per_scan_data['distance']=min(abs(208-scan_number), abs(248-scan_number))
        elif folder_name == '326_OD_2_GA_6x6_SSOCT_1': #65
            if (scan_number < 205 or scan_number > 245):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.append(min(abs(205-scan_number), abs(245-scan_number)))
#                 per_scan_data['distance']=min(abs(205-scan_number), abs(245-scan_number))
        elif folder_name == '326_OD_3_GA_6x6_SSOCT_1': #67
            if (scan_number < 193 or scan_number > 237):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.append(min(abs(193-scan_number), abs(237-scan_number)))
#                 per_scan_data['distance']=min(abs(193-scan_number), abs(237-scan_number))
        elif folder_name == '341_OS_1_GA_6x6_SSOCT_1': #69
            if (scan_number < 166 or scan_number > 413):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.append(min(abs(166-scan_number), abs(413-scan_number)))
#                 per_scan_data['distance']=min(abs(166-scan_number), abs(413-scan_number))
        elif folder_name == '345_OD_1_GA_6x6_SSOCT_1': #71
            ## changed it a bit
            if (scan_number>=163 and scan_number<=181)or(scan_number>=279 and scan_number<=297)or(scan_number>=343 and scan_number<=346):
                data_per.append(True)
                if (scan_number>=163 and scan_number<=181):
                    distance_per.append(min(abs(163-scan_number), abs(181-scan_number)))
#                     per_scan_data['distance']=min(abs(163-scan_number), abs(181-scan_number))
                elif (scan_number>=279 and scan_number<=297):
                    distance_per.append(min(abs(279-scan_number), abs(297-scan_number)))
#                     per_scan_data['distance']=min(abs(279-scan_number), abs(297-scan_number))
                else: 
                    distance_per.append(min(abs(343-scan_number), abs(346-scan_number)))
#                     per_scan_data['distance']=min(abs(343-scan_number), abs(346-scan_number))
            else:
                data_per.append(False)
        elif folder_name == '345_OD_2_GA_6x6_SSOCT_1': #75
            ## changed it a bit
            if (scan_number>=161 and scan_number<=181)or(scan_number>=272 and scan_number<=298)or(scan_number>=336 and scan_number<=340):
                data_per.append(True)
                if (scan_number>=161 and scan_number<=181):
                    distance_per.append(min(abs(161-scan_number), abs(181-scan_number)))
#                     per_scan_data['distance']=min(abs(161-scan_number), abs(181-scan_number))
                elif (scan_number>=272 and scan_number<=298):
                    distance_per.append(min(abs(272-scan_number), abs(298-scan_number)))
#                     per_scan_data['distance']=min(abs(272-scan_number), abs(298-scan_number))
                else: 
                    distance_per.append(min(abs(336-scan_number), abs(340-scan_number)))
#                     per_scan_data['distance']=min(abs(336-scan_number), abs(340-scan_number))
            else:
                data_per.append(False)
        elif folder_name == '345_OD_3_GA_6x6_SSOCT_1': #79
            ## changed it a bit
            if (scan_number>=167 and scan_number<=186)or(scan_number>=273 and scan_number<=304)or(scan_number>=338 and scan_number<=345):
                data_per.append(True)
                if (scan_number>=167 and scan_number<=186):
                    distance_per.append(min(abs(167-scan_number), abs(186-scan_number)))
#                     per_scan_data['distance']=min(abs(167-scan_number), abs(186-scan_number))
                elif (scan_number>=273 and scan_number<=304):
                    distance_per.append(min(abs(273-scan_number), abs(304-scan_number)))
#                     per_scan_data['distance']=min(abs(273-scan_number), abs(304-scan_number))
                else:
                    distance_per.append(min(abs(338-scan_number), abs(345-scan_number)))
#                     per_scan_data['distance']=min(abs(338-scan_number), abs(345-scan_number))
            else:
                data_per.append(False)
        elif folder_name == '345_OS_1_GA_6x6_SSOCT_1': #83
            ## changed it a bit
            if (scan_number>=214 and scan_number<=254)or(scan_number>=263 and scan_number<=282):
                data_per.append(True)
                if (scan_number>=214 and scan_number<=254):
#                     distance_per.append(min(abs(214-scan_number), abs(254-scan_number)))
                    per_scan_data['distance']=min(abs(214-scan_number), abs(254-scan_number))
                else: 
                    distance_per.append(min(abs(263-scan_number), abs(282-scan_number)))
#                     per_scan_data['distance']=min(abs(263-scan_number), abs(282-scan_number))
            else:
                data_per.append(False)
        elif folder_name == '345_OS_2_GA_6x6_SSOCT_1': #86
            ## changed it a bit
            if (scan_number>=210 and scan_number<=258)or(scan_number>=263 and scan_number<=287):
                data_per.append(True)
                if (scan_number>=210 and scan_number<=258):
                    distance_per.append(min(abs(210-scan_number), abs(258-scan_number)))
#                     per_scan_data['distance']=min(abs(210-scan_number), abs(258-scan_number))
                else: 
                    distance_per.append(min(abs(263-scan_number), abs(287-scan_number)))
#                     per_scan_data['distance']=min(abs(263-scan_number), abs(287-scan_number))
            else:
                data_per.append(False)
        elif folder_name == '345_OS_3_GA_6x6_SSOCT_1': #89
            if (scan_number < 205 or scan_number > 280):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.append(min(abs(205-scan_number), abs(280-scan_number)))
#                 per_scan_data['distance']=min(abs(205-scan_number), abs(280-scan_number))
        elif folder_name == '578_OD_1_GA_6x6_SSOCT_1': #91
            if (scan_number < 30 or scan_number > 314):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.append(min(abs(30-scan_number), abs(314-scan_number)))
#                 per_scan_data['distance']=min(abs(30-scan_number), abs(314-scan_number))
        elif folder_name == '578_OD_2_GA_6x6_SSOCT_1': #93
            if (scan_number < 27 or scan_number > 318):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.append(min(abs(27-scan_number), abs(318-scan_number)))
#                 per_scan_data['distance']=min(abs(27-scan_number), abs(318-scan_number))
        elif folder_name == '578_OS_1_GA_6x6_SSOCT_1': #95
            if (scan_number < 98 or scan_number > 443):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.append(min(abs(98-scan_number), abs(443-scan_number)))
#                 per_scan_data['distance']=min(abs(98-scan_number), abs(443-scan_number))
        elif folder_name == '578_OS_2_GA_6x6_SSOCT_1': #97
            if (scan_number < 90 or scan_number > 446):
                data_per.append(False)
            else:
                data_per.append(True)
                distance_per.append(in(abs(90-scan_number), abs(446-scan_number)))
#                 per_scan_data['distance']=min(abs(90-scan_number), abs(446-scan_number))
        else:
            print(picture)
            print("what the fuck")
        try:
            per_scan_data.loc[len(per_scan_data)-1]=data_per
            per_scan_data.loc[len(per_scan_data)]=distance_per
        except: 
            for value in len(data_per):
                print(data_per[value],distance_per[value])

# %%
per_scan_data

# %%
print('total scan count: ', len(per_scan_data))
print('positive: ', len(per_scan_data[per_scan_data['status']==True]))
print('negatives: ', len(per_scan_data[per_scan_data['status']==False]))

# %%
per_scan_data.to_csv("per_scan_data.csv", sep=',', index=False, encoding='utf-8')
